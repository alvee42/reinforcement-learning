# %% [markdown]
# # Reinforcement Learning
# #### Alvee Hoque 07/06/21
#
# This is a demo project attempting to explore the OpenAI's gym with the MountainCar-v0 game. Will be using Deep Q-Learning

# %% [markdown]
# ### Imports

# %%
import gym
import numpy as np

# %% [markdown]
# ### Environment

# %%
env = gym.make('MountainCar-v0')
env.reset()

print('Available Actions:',env.action_space.n)
print('High:',env.observation_space.high)
print('Low: ', env.observation_space.low)
# Out:
# Available Actions: 3
# High: [0.6  0.07]
# Low:  [-1.2  -0.07]

# %%
state = env.reset()

done = False
while not done: 
    action = 2 
    new_state, reward, done, _ = env.step(action)
    print(reward, new_state)
# Out:
# -1.0 [-0.45670166  0.00050535]
# -1.0 [-0.45569468  0.00100698]
# -1.0 [-0.45419346  0.00150121]
# -1.0 [-0.45220904  0.00198443]
# -1.0 [-0.44975595  0.00245309]
# -1.0 [-0.44685216  0.00290379]
# -1.0 [-0.4435189   0.00333326]
# -1.0 [-0.43978048  0.00373842]
# -1.0 [-0.4356641   0.00411639]
# -1.0 [-0.4311996  0.0044645]
# -1.0 [-0.42641925  0.00478035]
# -1.0 [-0.42135747  0.00506178]
# -1.0 [-0.41605053  0.00530694]
# -1.0 [-0.41053628  0.00551425]
# -1.0 [-0.40485384  0.00568245]
# -1.0 [-0.39904326  0.00581058]
# -1.0 [-0.39314526  0.005898  ]
# -1.0 [-0.38720088  0.00594438]
# -1.0 [-0.38125117  0.00594971]
# -1.0 [-0.37533692  0.00591425]
# -1.0 [-0.36949832  0.00583859]
# -1.0 [-0.36377475  0.00572357]
# -1.0 [-0.35820446  0.00557029]
# -1.0 [-0.35282435  0.00538011]
# -1.0 [-0.34766974  0.0051546 ]
# -1.0 [-0.34277419  0.00489555]
# -1.0 [-0.33816929  0.00460491]
# -1.0 [-0.33388447  0.00428481]
# -1.0 [-0.32994694  0.00393754]
# -1.0 [-0.32638146  0.00356548]
# -1.0 [-0.32321031  0.00317115]
# -1.0 [-0.32045317  0.00275714]
# -1.0 [-0.31812705  0.00232612]
# -1.0 [-0.31624621  0.00188084]
# -1.0 [-0.31482215  0.00142407]
# -1.0 [-0.31386352  0.00095863]
# -1.0 [-0.31337615  0.00048737]
# -1.0 [-3.13362984e-01  1.31607396e-05]
# -1.0 [-0.31382411 -0.00046113]
# -1.0 [-0.31475674 -0.00093263]
# -1.0 [-0.3161552  -0.00139846]
# -1.0 [-0.31801099 -0.00185579]
# -1.0 [-0.32031277 -0.00230178]
# -1.0 [-0.32304643 -0.00273366]
# -1.0 [-0.32619511 -0.00314868]
# -1.0 [-0.32973929 -0.00354418]
# -1.0 [-0.33365682 -0.00391753]
# -1.0 [-0.33792307 -0.00426625]
# -1.0 [-0.34251098 -0.00458791]
# -1.0 [-0.34739122 -0.00488024]
# -1.0 [-0.35253233 -0.0051411 ]
# -1.0 [-0.35790085 -0.00536852]
# -1.0 [-0.36346155 -0.0055607 ]
# -1.0 [-0.36917761 -0.00571606]
# -1.0 [-0.37501085 -0.00583324]
# -1.0 [-0.38092196 -0.00591111]
# -1.0 [-0.38687076 -0.00594881]
# -1.0 [-0.39281651 -0.00594575]
# -1.0 [-0.39871816 -0.00590165]
# -1.0 [-0.40453465 -0.00581649]
# -1.0 [-0.41022526 -0.00569061]
# -1.0 [-0.41574987 -0.00552461]
# -1.0 [-0.4210693  -0.00531944]
# -1.0 [-0.42614564 -0.00507634]
# -1.0 [-0.43094251 -0.00479687]
# -1.0 [-0.43542539 -0.00448288]
# -1.0 [-0.43956188 -0.00413649]
# -1.0 [-0.443322   -0.00376011]
# -1.0 [-0.44667838 -0.00335639]
# -1.0 [-0.44960657 -0.00292818]
# -1.0 [-0.45208515 -0.00247858]
# -1.0 [-0.45409597 -0.00201083]
# -1.0 [-0.4556243  -0.00152833]
# -1.0 [-0.45665891 -0.00103461]
# -1.0 [-0.4571922  -0.00053329]
# -1.0 [-4.57220257e-01 -2.80533093e-05]
# -1.0 [-0.45674287  0.00047739]
# -1.0 [-0.45576354  0.00097933]
# -1.0 [-0.45428947  0.00147407]
# -1.0 [-0.45233149  0.00195799]
# -1.0 [-0.44990394  0.00242754]
# -1.0 [-0.44702462  0.00287932]
# -1.0 [-0.44371456  0.00331006]
# -1.0 [-0.43999792  0.00371664]
# -1.0 [-0.43590173  0.00409619]
# -1.0 [-0.43145571  0.00444602]
# -1.0 [-0.42669199  0.00476372]
# -1.0 [-0.42164488  0.00504711]
# -1.0 [-0.41635056  0.00529432]
# -1.0 [-0.41084679  0.00550377]
# -1.0 [-0.40517263  0.00567416]
# -1.0 [-0.39936809  0.00580453]
# -1.0 [-0.39347387  0.00589422]
# -1.0 [-0.38753098  0.00594289]
# -1.0 [-0.3815805   0.00595048]
# -1.0 [-0.37566322  0.00591728]
# -1.0 [-0.36981939  0.00584383]
# -1.0 [-0.36408843  0.00573096]
# -1.0 [-0.35850866  0.00557977]
# -1.0 [-0.35311706  0.0053916 ]
# -1.0 [-0.34794906  0.005168  ]
# -1.0 [-0.3430383   0.00491076]
# -1.0 [-0.33841648  0.00462181]
# -1.0 [-0.33411319  0.00430329]
# -1.0 [-0.33015573  0.00395746]
# -1.0 [-0.32656901  0.00358671]
# -1.0 [-0.32337546  0.00319355]
# -1.0 [-0.3205949   0.00278056]
# -1.0 [-0.31824448  0.00235042]
# -1.0 [-0.31633863  0.00190585]
# -1.0 [-0.31488898  0.00144965]
# -1.0 [-0.31390437  0.00098461]
# -1.0 [-0.31339076  0.0005136 ]
# -1.0 [-3.13351283e-01  3.94819735e-05]
# -1.0 [-0.31378616 -0.00043488]
# -1.0 [-0.31469277 -0.00090661]
# -1.0 [-0.3160656  -0.00137283]
# -1.0 [-0.3178963 -0.0018307]
# -1.0 [-0.3201737 -0.0022774]
# -1.0 [-0.32288383 -0.00271013]
# -1.0 [-0.32600999 -0.00312616]
# -1.0 [-0.32953279 -0.0035228 ]
# -1.0 [-0.33343025 -0.00389746]
# -1.0 [-0.33767785 -0.0042476 ]
# -1.0 [-0.34224867 -0.00457082]
# -1.0 [-0.34711351 -0.00486484]
# -1.0 [-0.352241  -0.0051275]
# -1.0 [-0.35759782 -0.00535682]
# -1.0 [-0.36314882 -0.005551  ]
# -1.0 [-0.36885726 -0.00570844]
# -1.0 [-0.37468502 -0.00582776]
# -1.0 [-0.38059285 -0.00590783]
# -1.0 [-0.38654063 -0.00594778]
# -1.0 [-0.39248762 -0.00594699]
# -1.0 [-0.39839279 -0.00590517]
# -1.0 [-0.40421508 -0.00582229]
# -1.0 [-0.40991372 -0.00569864]
# -1.0 [-0.41544857 -0.00553485]
# -1.0 [-0.42078039 -0.00533182]
# -1.0 [-0.42587117 -0.00509079]
# -1.0 [-0.43068446 -0.00481329]
# -1.0 [-0.43518562 -0.00450116]
# -1.0 [-0.43934213 -0.00415651]
# -1.0 [-0.44312385 -0.00378172]
# -1.0 [-0.44650329 -0.00337944]
# -1.0 [-0.4494558  -0.00295251]
# -1.0 [-0.45195982 -0.00250401]
# -1.0 [-0.453997   -0.00203718]
# -1.0 [-0.4555524  -0.00155541]
# -1.0 [-0.45661462 -0.00106222]
# -1.0 [-0.45717585 -0.00056122]
# -1.0 [-4.57231952e-01 -5.61059841e-05]
# -1.0 [-4.56782527e-01  4.49424883e-04]
# -1.0 [-0.45583087  0.00095165]
# -1.0 [-0.45438399  0.00144689]
# -1.0 [-0.45245249  0.0019315 ]
# -1.0 [-0.45005055  0.00240194]
# -1.0 [-0.44719575  0.0028548 ]
# -1.0 [-0.44390897  0.00328678]
# -1.0 [-0.44021419  0.00369478]
# -1.0 [-0.43613829  0.0040759 ]
# -1.0 [-0.43171084  0.00442745]
# -1.0 [-0.42696386  0.00474698]
# -1.0 [-0.42193153  0.00503233]
# -1.0 [-0.41664994  0.00528159]
# -1.0 [-0.41115677  0.00549317]
# -1.0 [-0.40549102  0.00566576]
# -1.0 [-0.39969265  0.00579837]
# -1.0 [-0.39380233  0.00589032]
# -1.0 [-0.38786106  0.00594126]
# -1.0 [-0.38190993  0.00595113]
# -1.0 [-0.37598975  0.00592018]
# -1.0 [-0.37014081  0.00584894]
# -1.0 [-0.36440257  0.00573823]
# -1.0 [-0.35881344  0.00558914]
# -1.0 [-0.35341046  0.00540297]
# -1.0 [-0.34822916  0.0051813 ]
# -1.0 [-0.34330329  0.00492587]
# -1.0 [-0.33866466  0.00463863]
# -1.0 [-0.33434297  0.00432169]
# -1.0 [-0.33036566  0.00397731]
# -1.0 [-0.32675778  0.00360788]
# -1.0 [-0.32354189  0.00321589]
# -1.0 [-0.32073795  0.00280393]
# -1.0 [-0.31836328  0.00237467]
# -1.0 [-0.31643245  0.00193083]
# -1.0 [-0.31495725  0.0014752 ]
# -1.0 [-0.31394667  0.00101058]
# -1.0 [-0.31340684  0.00053983]
# -1.0 [-3.13341040e-01  6.58024721e-05]
# -1.0 [-0.31374966 -0.00040862]
# -1.0 [-0.31463023 -0.00088057]
# -1.0 [-0.3159774  -0.00134717]
# -1.0 [-0.31778298 -0.00180558]
# -1.0 [-0.32003595 -0.00225297]
# -1.0 [-0.3227225  -0.00268655]
# -1.0 [-0.32582608 -0.00310358]
# -1.0 [-0.32932744 -0.00350136]
# -1.0 [-0.33320475 -0.0038773 ]
# -1.0 [-0.33743362 -0.00422887]

# %% [markdown]
# #### Notes:
# The reward is always -1.0 and the new state values are position and velocity.

# %%
DISCRETE_OS_SIZE = [20,20]
discrete_os_win_size = (env.observation_space.high - env.observation_space.low)/DISCRETE_OS_SIZE
print(discrete_os_win_size)
# Out:
# [0.09  0.007]

# %%
# Making q table
q_table = np.random.uniform(low=-2, high=0, 
                            size=(DISCRETE_OS_SIZE + [env.action_space.n]))

# %%
# new q states formula: 
#new_q = (1 - LEARNING_RATE) * current_q + LEARNING_RATE * (reward + DISCOUNT * max_future_q)

# %%
# Q-Learning Settings: 
learning_rate = 0.1
discount = 0.95
episodes = 2000

# Exploration setting
epsilon = 1
start_epsilon_decay = 1 
end_epsilon_decay = episodes//2
epsilon_decay_value = epsilon/(end_epsilon_decay - start_epsilon_decay)


show_every = 500

# %%
def get_discrete_state(state):
    discrete_state = (state -env.observation_space.low)/discrete_os_win_size
    return tuple(discrete_state.astype(int))

# %%
for episode in range(episodes):
    discrete_state = get_discrete_state(env.reset())
    done = False
    
    if episode % show_every == 0:
        render = True
        print(episode)
        
    else: 
        render = False
    
    while not done: 
        action = np.argmax(q_table[discrete_state])
        new_state, reward, done, _ = env.step(action)
        new_discrete_state = get_discrete_state(new_state)
        
        if episode % show_every == 0: 
            
            env.render()

        if not done:
            # max Q val for next step
            max_future_q = np.max(q_table[new_discrete_state])

            # current Q val
            current_q = q_table[discrete_state + (action,)]

            # new Q val 
            new_q = (1-learning_rate) * current_q + learning_rate * (reward + discount * max_future_q)

            # updating Q table
            q_table[discrete_state + (action,)] = new_q

        elif new_state[0] >= env.goal_position:
            q_table[discrete_state + (action,)] = 0 

        discrete_state = new_discrete_state
    
env.close()
# Out:
# 0
# 500
# 1000
# 1500
